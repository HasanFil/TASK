# %% [markdown]
# <a href="https://colab.research.google.com/github/HasanFil/TASK/blob/main/HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Görüntü işleme aşamlarını sırası ile tarif ediniz.

# %% [markdown]
# - Görüntü işleme temel olarak aşağıdaki üç adımı içerir.
#
#   · Görüntünün optik tarayıcı ile veya dijital fotoğraflarla alınması.
#
#   · Veri sıkıştırma, görüntü iyileştirme ve uydu fotoğrafları gibi insan gözü olmayan lekelenme kalıplarını içeren görüntüyü analiz etme-kullanma.
#
#   · Çıktı, sonuçların görüntü analizine dayalı olarak değiştirilmiş, kullanıma hazır hale getirme.

# %% [markdown]
# Feature map veya bir sonraki layerın boyutlarını belirleyen özellikler nelerdir. Açıklayınız.

# %% [markdown]
# - Kernel size( K X K )
# - Depth
# - Stride
# - Padding

# %% [markdown]
# Softmax nedir? Ne işe yarar?

# %% [markdown]
# - Softmax fonksiyonu çoklu sınıflandırma problemleri için kullanılır. Verilen her bir girdinin bir sınıfa ait olma olasılığını gösteren [0,1] arası çıktılar üretmektedir.

# %% [markdown]
# Aktivasyon fonskiyonlarının kullanım amaçları nedir? 3 adet örnek veriniz. Amaçlarını açıklayınız. Şekillerini çiziniz.

# %% [markdown]
# - Tek dereceli olmayan problemlerinde çözüme erişmesi için kullanılan fonksiyonlardır. Aktivasyon fonksiyonu kullanılmayan bir sinir ağı çok sınırlı yani sadece bir lineer regresyon gibi olacaktır. Aşağıda 3 tane sık kullanılan aktivasyon fonksiyonunun grafiği verilmiştir.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ReLU Fonksiyonu: Doğrultulmuş lineer birim (rectified linear unit- RELU) doğrusal olmayan bir fonksiyondur. ReLU fonksiyonu negatif girdiler için 0 değerini alırken, x pozitif girdiler için x değerini almaktadır.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ReLU’dan en önemli farkı negatif bölgede değer alır. Swish’in negatif bölgede aldığı değerler doğrusal değildir!
#
#
# f(x)=2x*sigmoid(beta*x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Sigmoid: Girdilerin değeri ne olursa olsun (negatif veya pozitif), 0 ile 1 arasında bir sonuç döndürür. Yani çıkan değer uçuk bir değer olmaz.

# %% [markdown]
# 32,32 lik image oldğunu düşünelim 2,2 like Max pooling sonucunda çıktı hangi boyutta olur?

# %%
# ((n-f)/s)+1 x ((n-f)/s)+1

# %% [markdown]
# - Stride değeri default olarak 1 gelir. ((32-2)/1)+1=31, bu yüzden 31x31 image elde ederiz.

# %% [markdown]
# 6 soruya ek olarak eğer bu işlemler esnasında stride=2 olursa çıktı boyutu nasıl olur?

# %% [markdown]
# - Stride değeri 2 olursa ((32-2)/2)+1=16 yani 16x16-lık bir image elde ederiz.

# %% [markdown]
# Droupout'un amacı nedir?

# %% [markdown]
# - Modelde overfittingi engellemek amacıyla bazı katmanları unutmasıdır.
# Yüzde kaç ise ona göre node siler.

# %% [markdown]
# Görüntü işleme yöntemleri için kullanılan 3 adet framework belirtiniz.

# %% [markdown]
# - Opencv
# - Tensorflow
# - MATLAB

# %% [markdown]
# Niçin imajlar için ANN yerine CNN kullanıyoruz?

# %% [markdown]
# - ANN, veriyi ölçeklendirme işleminde yetersiz olduğu için görüntü sınıflandırma problemleri zorlaşır çünkü 2 boyutlu görüntülerin 1 boyutlu vektörlere dönüştürülmesi gerekir. CNN ile veriye oldukça farklı işlemler uygulayabilip veriden çok farklı ve anlamlı özellikler elde edebiliyoruz. CNN'in en büyük avantajı, önemli özellikleri herhangi bir insan gözetimi olmadan otomatik olarak algılamasıdır. Bu nedenle CNN, bilgisayarla görme ve görüntü sınıflandırma sorunlarına ideal bir çözüm olacaktır.

# %% [markdown]
# CNN ağları için dimension reduction mümkün müdür? Mümkünse nasıl ve hangi katmanlarda uygulanabilir?

# %% [markdown]
# - Evet mümkündür. Dimension reduction işlemini pooling ile sağlarız. Reduce the size yapar. Max pooling, average pooling, sum pooling algoritmaları vardır. En popüleri max poolingdir.

# %% [markdown]
#  5,5 bir imaja 3,3 lük bir filtre uygulandığında stride=1 olacak şekilde o-elde edilen outputun boyutunun 5,5 olması niçin ne yapabiliriz?

# %%
# ((5-3+2p)/1)+1=5 için p=1

# %% [markdown]
# - Zero padding ile imajımızın çevresini 0'lar ile doldurabilir.
