# %% [markdown]
# <a href="https://colab.research.google.com/github/HasanFil/TASK/blob/main/Task_4A_4B_4C_4D_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("Temporary_data3_-_Copy.xlsx")
data.head()
# Out:
#    SEX  EDUC  MARISTAT  INDEPEND  RESIDENC  NACCFAM  ANYMEDS  SMOKYRS  \
# 0    2    18         1         1         1        1        1        0
# 1    1    11         1         1         1        1        1        0
# 2    2    16         1         1         1        1        1       10
# 3    1    14         1         1         1        0        1        0
# 4    1    16         1         1         2        0        1       50
#
#    NACCTBI  DIABETES  ...   RSUPFR  RSUPFRM  RSUPPAR  RSUPPARM  RSUPTEM  \
# 0        0         0  ...  27.9038   2.2157  10.3481    1.7014  13.4250
# 1        0         0  ...  29.0600   2.6900   9.2500    1.6300  14.8800
# 2        0         1  ...  33.0000   2.5400  13.6900    1.5600  16.2300
# 3        0         1  ...  31.6800   2.4100   9.6400    1.4500  15.1100
# 4        0         0  ...  28.0631   1.9501   9.1125    1.0427  13.3763
#
#    RSUPTEMM  RSUPMAR  RSUPMARM  RTRTEM  RTRTEMM
# 0    1.7419   9.8700    1.6792  0.8906   1.1947
# ...

# %%
data["CDRGLOB"]
# Out:
# 0       0
# 1       2
# 2       0
# 3       0
# 4       1
#        ..
# 1349    1
# 1350    2
# 1351    0
# 1352    0
# 1353    0
# Name: CDRGLOB, Length: 1354, dtype: int64

# %% [markdown]
# TASK-4A: Please present a descriptive statistics analysis to provide a general understanding of the dataset. (describe)

# %%
data.describe()
# Out:
#                SEX         EDUC     MARISTAT     INDEPEND     RESIDENC  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000
# mean      1.573855    15.223781     1.658789     1.316100     1.112999
# std       0.494698     3.418699     1.136754     0.598538     0.360372
# min       1.000000     0.000000     1.000000     1.000000     1.000000
# 25%       1.000000    12.000000     1.000000     1.000000     1.000000
# 50%       2.000000    16.000000     1.000000     1.000000     1.000000
# 75%       2.000000    18.000000     2.000000     2.000000     1.000000
# max       2.000000    25.000000     6.000000     4.000000     4.000000
#
#            NACCFAM      ANYMEDS      SMOKYRS      NACCTBI     DIABETES  ...  \
# count  1354.000000  1354.000000  1354.000000  1354.000000  1354.000000  ...
# mean      0.631462     0.952733     9.754801     0.127031     0.192762  ...
# std       0.482586     0.212289    14.351222     0.333131     0.432160  ...
# ...

# %% [markdown]
# TASK-4B: Please provide the visual illustrations of the dataset that will demonstrate the insightful distributions with respect to the target column (CDRGLOB: the level of the Alzheimer Disease -AD)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = data ["EDUC"]
y = data["SMOKYRS"]
labels = data["CDRGLOB"]
plt.scatter(x, y, s=20, cmap = "viridis", c=labels, alpha=0.5)
plt.xlabel("Education Years")
plt.ylabel("Smoking Years")
plt.title("Edu-Smk Scatter")
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = data ["NACCBMI"]
y = data["SMOKYRS"]
labels = data["CDRGLOB"]
plt.scatter(x, y, s=20, cmap = "viridis", c=labels, alpha=0.5)
plt.xlabel("NACCBMI")
plt.ylabel("Smoking Years")
plt.title("Nac-Smk Scatter")
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = data ["NACCBMI"]
y = data["EDUC"]
labels = data["CDRGLOB"]
plt.scatter(x, y, s=20, cmap = "viridis", c=labels, alpha=0.5)
plt.xlabel("NACCBMI")
plt.ylabel("Smoking Years")
plt.title("Nac-Edu Scatter")
plt.colorbar()
plt.show()

# %% [markdown]
# TASK-4C: Please provide a correlation analysis between two different variables/features and argue for the analysis outputs.

# %%
data.corr()
# Out:
#                SEX      EDUC  MARISTAT  INDEPEND  RESIDENC   NACCFAM  \
# SEX       1.000000 -0.129742  0.244620 -0.098873  0.054726 -0.005097
# EDUC     -0.129742  1.000000 -0.021607 -0.108642 -0.030139  0.062121
# MARISTAT  0.244620 -0.021607  1.000000 -0.099897  0.101406 -0.034038
# INDEPEND -0.098873 -0.108642 -0.099897  1.000000  0.115258 -0.036503
# RESIDENC  0.054726 -0.030139  0.101406  0.115258  1.000000 -0.057857
# NACCFAM  -0.005097  0.062121 -0.034038 -0.036503 -0.057857  1.000000
# ANYMEDS  -0.008961  0.052266  0.018874  0.065325  0.002240  0.002984
# SMOKYRS  -0.115607 -0.102343  0.069213  0.029422  0.057381 -0.013057
# NACCTBI  -0.056971 -0.017841  0.007199  0.009751 -0.002683  0.006383
# DIABETES -0.023426 -0.157286  0.034688 -0.038581  0.087832 -0.095018
# ALCOHOL  -0.124100 -0.108352  0.008503  0.075249  0.043491 -0.012000
# HXHYPER  -0.067217 -0.164950  0.060868  0.047143  0.108038 -0.106918
# HYPERCHO -0.059083 -0.071618  0.036017  0.097293 -0.004716 -0.060790
# ...

# %% [markdown]
# TASK-4D: Please provide several pivot tables for insightful illustrations both via tables and figures.

# %%
rsupfrm = pd.qcut(data["RSUPFRM"], 4)
data.pivot_table("HIPPOVOL", index="CDRGLOB", columns=rsupfrm)
# Out:
# RSUPFRM  (0.901, 1.988]  (1.988, 2.198]  (2.198, 2.376]  (2.376, 4.06]
# CDRGLOB
# 0              6.049632        6.398172        6.541058       6.354542
# 1              5.576129        5.969927        5.909631       5.727940
# 2              5.120482        5.503983        5.467128       5.553428
# 3              4.853755        4.793700        5.150913       4.973567

# %%
data.pivot_table("HIPPOVOL", index="CDRGLOB", columns=rsupfrm, aggfunc="count")
# Out:
# RSUPFRM  (0.901, 1.988]  (1.988, 2.198]  (2.198, 2.376]  (2.376, 4.06]
# CDRGLOB
# 0                    93             143             179            231
# 1                   154             134             121             87
# 2                    72              46              29             18
# 3                    20              16               8              3

# %%
data.pivot_table("HIPPOVOL", index=["CDRGLOB","SEX"], columns=rsupfrm)
# Out:
# RSUPFRM      (0.901, 1.988]  (1.988, 2.198]  (2.198, 2.376]  (2.376, 4.06]
# CDRGLOB SEX
# 0       1          6.283643        6.736349        6.743624       6.709332
#         2          5.895018        6.221888        6.453549       6.187317
# 1       1          5.742266        6.224907        6.194190       6.183652
#         2          5.386917        5.682568        5.638840       5.475671
# 2       1          5.336875        5.882572        5.781056       6.047600
#         2          4.849991        5.053281        4.953427       4.935713
# 3       1          5.131185        4.648311        5.574850       4.460000
#         2          4.338529        4.980629        4.726975       5.230350

# %%
data.pivot_table("HIPPOVOL", index=["CDRGLOB","SEX"], columns=rsupfrm2).plot(kind="bar")
plt.legend()

# %%
rsupfrm2 = pd.qcut(data["RSUPFRM"], 2)
data.pivot_table("HIPPOVOL", index=["CDRGLOB","SEX"], columns=["INDEPEND", rsupfrm2])
# Out:
# INDEPEND                 1                            2                \
# RSUPFRM     (0.901, 2.198] (2.198, 4.06] (0.901, 2.198] (2.198, 4.06]
# CDRGLOB SEX
# 0       1         6.548528      6.723799       5.951000           NaN
#         2         6.100493      6.307426       6.052750      6.011500
# 1       1         6.041605      6.319668       5.771106      5.846200
#         2         5.551774      5.660755       5.478162      5.386495
# 2       1         5.610553      5.867371       5.640327      5.812353
#         2         5.128877      3.971100       4.929285      5.029487
# 3       1              NaN           NaN       4.636067      4.460000
#         2         4.968200           NaN       4.326967      4.650000
#
# INDEPEND                 3                            4
# RSUPFRM     (0.901, 2.198] (2.198, 4.06] (0.901, 2.198] (2.198, 4.06]
# CDRGLOB SEX
# 0       1              NaN           NaN            NaN           NaN
# ...

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
